# %%
import skvideo.io
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage import restoration
import numpy as np
from scipy.misc import imresize,imread,imsave
plt.rcParams['figure.figsize'] = 10,10
# Out:
# /usr/local/lib/python3.5/dist-packages/skvideo/__init__.py:356: UserWarning: avconv/avprobe not found in path:
#   warnings.warn("avconv/avprobe not found in path: " + str(path), UserWarning)

# %%
##load the video, shape=(Frames, Height, Width, Channels)
videodata = skvideo.io.vread('./data/yingying.mp4')
videodata.shape
# Out:
# (707, 720, 1280, 3)

# %%
# A typical image centered around the car
img = videodata[602,100:200,200:300,:]
plt.imshow(img)
#plt.imshow(imresize(img,(300,300)))

# %%
## Car head images at different time (may try to use all frames' information)
N=601
y,x=142,234
x2 = imresize(np.array(videodata[N,y:y+50,x:x+50,:],dtype=np.float)/255.0,(200,200))
plt.imshow(x2)
plt.show()

N=602
y,x=150,200
x1 = imresize(np.array(videodata[N,y:y+50,x:x+50,:],dtype=np.float)/255.0,(200,200))
plt.imshow(x1)

# %%
### sample license plate images:
W,H=12,8
x,y=203,168
plt.imshow(videodata[602,y:y+H,x:x+W,:])

# %%
## How a downsampled license plate looks like: (image from internet)
IL1 = imread('./data/IL1.jpg')
plt.imshow(IL1)
plt.show()
plt.imshow(imresize(IL1,(8,12)))
